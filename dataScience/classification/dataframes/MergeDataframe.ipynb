# %%
import pandas as pd
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
family_df = pd.read_pickle("/content/drive/MyDrive/SDGP code/Classification/dataframes/family-dataframe.pickle")
crime_df = pd.read_pickle("/content/drive/MyDrive/SDGP code/Classification/dataframes/crime-dataframe.pickle")
employment_df = pd.read_pickle("/content/drive/MyDrive/SDGP code/Classification/dataframes/employment-dataframe.pickle")
rights_df = pd.read_pickle("/content/drive/MyDrive/SDGP code/Classification/dataframes/rights-dataframe.pickle")

df = family_df.append(crime_df, ignore_index = True) 

df2 = df.append(employment_df, ignore_index = True) 

full_df = df2.append(rights_df, ignore_index = True) 

full_df
# Out:
#         category                                            legName  \
# 0         family  Rectification of a Muslim Marriage Register of...
# 1         family  Rectification of a Muslim Marriage Register of...
# 2         family  Rectification of a Muslim Marriage Register of...
# 3         family                   Kandyan Marriage and Divorce Act
# 4         family                   Kandyan Marriage and Divorce Act
# 5         family                   Kandyan Marriage and Divorce Act
# 6         family                   Kandyan Marriage and Divorce Act
# 7         family                   Kandyan Marriage and Divorce Act
# 8         family                   Kandyan Marriage and Divorce Act
# 9         family                   Kandyan Marriage and Divorce Act
# 10        family                   Kandyan Marriage and Divorce Act
# 11        family                   Kandyan Marriage and Divorce Act
# 12        family                   Kandyan Marriage and Divorce Act
# ...

# %%
full_df.to_pickle("/content/drive/MyDrive/SDGP code/Classification/dataframes/full-dataframe.pickle")
